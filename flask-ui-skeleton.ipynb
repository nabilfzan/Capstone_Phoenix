# %% [markdown]
# # Capstone Project Flask UI

# %% [markdown]
# Pada capstone ini anda diminta untuk membangun sebuah Flask UI sederhana yang berisi beberapa tampilan plot dari skeleton yang sudah disediakan dan satu plot tambahan berdasarkan analisis anda.
#
# File ini dapat dimanfaatkan untuk membantu anda dalam proses wrangling dan visualization. Apabila proses wrangling sudah tepat dan hasil visualisasi sudah sesuai dengan ketentuan, anda dapat memindahkan kembali kode program yang sudah anda lengkapi ke dalam file `app.py`.

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# **Import library**

# %%
from flask import Flask, render_template
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from io import BytesIO
import base64

# %% [markdown]
# **Load data**
#
# Bacalah file `googleplaystore.csv` data dan simpan ke objek dataframe dengan nama playstore

# %%
#playstore.head()

# %%
playstore = pd.read_csv('data/googleplaystore.csv')

# %% [markdown]
# **Data Cleansing**

# %% [markdown]
# **_Task 1:_** Hapus data yang duplikat berdasarkan kolom App, dengan tetap keep data pertama (hint : gunakan parameter subset)

# %%
playstore.drop_duplicates(subset = ['App'], inplace=True)

# %% [markdown]
# Bagian ini untuk menghapus row 10472 karena nilai data tersebut tidak tersimpan pada kolom yang benar

# %%
playstore.drop([10472], inplace=True)

# %% [markdown]
# **_Task 2:_** Cek tipe data kolom Category. Jika masih tersimpan dengan format tipe data yang salah, ubah ke tipe data yang sesuai

# %%
playstore.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
playstore.Category = playstore['Category'].astype('category')

# %% [markdown]
# **_Task 3:_** Pada kolom Installs Buang tanda koma(,) dan tanda tambah(+) kemudian ubah tipe data menjadi integer

# %%
playstore.Installs = playstore['Installs'].apply(lambda x: x.replace(',',''))
playstore.Installs = playstore['Installs'].apply(lambda x: x.replace('+',''))

# %% [markdown]
# Bagian ini untuk merapikan kolom Size, Anda tidak perlu mengubah apapun di bagian ini

# %%
playstore['Size'].replace('Varies with device', np.nan, inplace = True ) 
playstore.Size = (playstore.Size.replace(r'[kM]+$', '', regex=True).astype(float) * \
             playstore.Size.str.extract(r'[\d\.]+([kM]+)', expand=False)
            .fillna(1)
            .replace(['k','M'], [10**3, 10**6]).astype(int))
playstore['Size'].fillna(playstore.groupby('Category')['Size'].transform('mean'),inplace = True)

# %% [markdown]
# **_Task 4:_** Pada kolom Price, buang karakater $ pada nilai Price lalu ubah tipe datanya menjadi float

# %%
playstore.Price = playstore['Price'].apply(lambda x: x.replace('$',''))
playstore.Price = playstore['Price'].astype('float')

# %% [markdown]
# Ubah tipe data Reviews, Size, Installs ke dalam tipe data integer

# %%
##code here

playstore.Size = playstore['Size'].astype('int64')

# %%
playstore.Reviews = playstore['Reviews'].astype('int64')

# %%
playstore.Installs = playstore['Installs'].astype('int')

# %%
playstore.dtypes
# Out:
# App                 object
# Category          category
# Rating             float64
# Reviews              int64
# Size                 int64
# Installs             int32
# Type                object
# Price              float64
# Content Rating      object
# Genres              object
# Last Updated        object
# Current Ver         object
# Android Ver         object
# dtype: object

# %% [markdown]
# ## Data Wrangling

# %%
df2 = playstore.copy()

# %% [markdown]
# **_Task 5:_** Dataframe top_category dibuat untuk menyimpan frekuensi aplikasi untuk setiap Category.
# Gunakan crosstab untuk menghitung frekuensi aplikasi di setiap category kemudian gunakan `Jumlah`
# sebagai nama kolom dan urutkan nilai frekuensi dari nilai yang paling banyak. Terakhir reset index dari dataframe top_category.

# %%
top_category = pd.crosstab(index= df2['Category'],
            columns= 'Jumlah',
          
           ).sort_values(by='Jumlah',ascending=False)

# %%
top_category.head()
# Out:
# col_0     Jumlah
# Category
# FAMILY      1832
# GAME         959
# TOOLS        827
# BUSINESS     420
# MEDICAL      395

# %% [markdown]
# **_Task 6:_** Ini adalah bagian untuk melengkapi konten value box
# most category mengambil nama category paling banyak mengacu pada dataframe `top_category`
# total mengambil frekuensi/jumlah category paling banyak mengacu pada dataframe `top_category`

# %%
#

# %%
most_categories = df2[df2['Category']== 'FAMILY']
total = most_categories

# %%
total
# Out:
#                                                      App Category  Rating  \
# 2017                        Jewels Crush- Match 3 Puzzle   FAMILY     4.4
# 2018                                    Coloring & Learn   FAMILY     4.4
# 2019                                             Mahjong   FAMILY     4.5
# 2020   Super ABC! Learning games for kids! Preschool ...   FAMILY     4.6
# 2021                                       Toy Pop Cubes   FAMILY     4.5
# ...                                                  ...      ...     ...
# 10821                                            Poop FR   FAMILY     NaN
# 10827                                 Fr Agnel Ambarnath   FAMILY     4.2
# 10834                                      FR Calculator   FAMILY     4.0
# 10836                                   Sya9a Maroc - FR   FAMILY     4.5
# 10837                   Fr. Mike Schmitz Audio Teachings   FAMILY     5.0
#
#        Reviews      Size  Installs  Type  Price Content Rating  \
# 2017     14774  19000000   1000000  Free    0.0       Everyone
# 2018     12753  51000000   5000000  Free    0.0       Everyone
# 2019     33983  22000000   5000000  Free    0.0       Everyone
# 2020     20267  46000000   1000000  Free    0.0       Everyone
# 2021      5761  21000000   1000000  Free    0.0       Everyone
# ...        ...       ...       ...   ...    ...            ...
# 10821        6   2500000        50  Free    0.0       Everyone
# 10827      117  13000000      5000  Free    0.0       Everyone
# 10834        7   2600000       500  Free    0.0       Everyone
# 10836       38  53000000      5000  Free    0.0       Everyone
# 10837        4   3600000       100  Free    0.0       Everyone
#
#                        Genres    Last Updated Current Ver   Android Ver
# 2017       Casual;Brain Games   July 23, 2018    1.9.3901  4.0.3 and up
# 2018   Educational;Creativity   July 17, 2018        1.49  4.0.3 and up
# 2019       Puzzle;Brain Games  August 2, 2018   1.24.3181  4.0.3 and up
# 2020    Educational;Education   July 16, 2018     1.1.6.7    4.1 and up
# 2021       Casual;Brain Games    July 4, 2018    1.8.3181  4.0.3 and up
# ...                       ...             ...         ...           ...
# 10821           Entertainment    May 29, 2018         1.0  4.0.3 and up
# 10827               Education   June 13, 2018      2.0.20  4.0.3 and up
# 10834               Education   June 18, 2017       1.0.0    4.1 and up
# 10836               Education   July 25, 2017        1.48    4.1 and up
# 10837               Education    July 6, 2018         1.0    4.1 and up
#
# [1832 rows x 13 columns]

# %% [markdown]
# `rev_table` adalah tabel yang berisi 10 aplikasi yang paling banyak direview oleh pengguna.
# Silahkan melakukan agregasi data yang tepat menggunakan `groupby` untuk menampilkan 10 aplikasi yang diurutkan berdasarkan jumlah Review pengguna.
#
# Tabel yang ditampilkan terdiri dari 4 kolom yaitu nama Category, nama App, total Reviews, dan rata-rata Rating.
# Pindahkan kode wrangling yang disimpan dalam variable `rev_table` pada `blank code` yang telah di chaining dengan kode `.to_html`.

# %%
rev_table = df2.groupby('Category').agg(
    {'App':'first',
     'Reviews': 'sum',
     'Rating': 'mean'
     }
            ).sort_values(by='Reviews',ascending=False)

# %% [markdown]
# Apabila menuliskan kode program yang tepat maka hasil wrangling adalah sebagai berikut :

# %%
rev_table
# Out:
#                                                                    App  \
# Category
# GAME                                                            ROBLOX
# COMMUNICATION                 Messenger – Text and Video Chat for Free
# TOOLS                                                Moto File Manager
# SOCIAL                                                        Facebook
# FAMILY                                    Jewels Crush- Match 3 Puzzle
# PHOTOGRAPHY                                   TouchNote: Cards & Gifts
# VIDEO_PLAYERS                                                  YouTube
# PRODUCTIVITY                                            Microsoft Word
# PERSONALIZATION                                          Nova Launcher
# SHOPPING                                            Amazon for Tablets
# SPORTS                                                            ESPN
# ENTERTAINMENT                                                  Netflix
# TRAVEL_AND_LOCAL     Expedia Hotels, Flights & Car Rental Travel Deals
# NEWS_AND_MAGAZINES   Fox News – Breaking News, Live Video & News Al...
# HEALTH_AND_FITNESS                         Home Workout - No Equipment
# MAPS_AND_NAVIGATION  Waze - GPS, Maps, Traffic Alerts & Live Naviga...
# BOOKS_AND_REFERENCE                               Wattpad 📖 Free Books
# EDUCATION                               Duolingo: Learn Languages Free
# FINANCE                                                         K PLUS
# WEATHER              The Weather Channel: Rain Forecast & Storm Alerts
# LIFESTYLE                                   Dollhouse Decorating Games
# BUSINESS                                  Visual Voicemail by MetroPCS
# FOOD_AND_DRINK                                              McDonald's
# DATING                                       Moco+ - Chat, Meet People
# COMICS                                      LINE WEBTOON - Free Comics
# HOUSE_AND_HOME       Zillow: Find Houses for Sale & Apartments for ...
# ART_AND_DESIGN          Photo Editor & Candy Camera & Grid & ScrapBook
# MEDICAL                                     Monash Uni Low FODMAP Diet
# AUTO_AND_VEHICLES                          Monster Truck Stunt 3D 2019
# PARENTING                                                   Baby Names
# LIBRARIES_AND_DEMO                              Public Digital Library
# BEAUTY                                      Hush - Beauty for Everyone
# EVENTS                                              All Events in City
#
#                        Reviews    Rating
# Category
# GAME                 622298709  4.247368
# COMMUNICATION        285811368  4.121484
# TOOLS                229356578  4.039554
# SOCIAL               227927801  4.247291
# FAMILY               143825488  4.179664
# PHOTOGRAPHY          105351270  4.157414
# VIDEO_PLAYERS         67484568  4.044595
# PRODUCTIVITY          55590649  4.183389
# PERSONALIZATION       53543080  4.332215
# SHOPPING              44551730  4.230000
# SPORTS                35348813  4.216154
# ENTERTAINMENT         34762650  4.135294
# TRAVEL_AND_LOCAL      26819741  4.069519
# NEWS_AND_MAGAZINES    23130228  4.121569
# HEALTH_AND_FITNESS    21361355  4.243033
# MAPS_AND_NAVIGATION   17729148  4.036441
# BOOKS_AND_REFERENCE   16721314  4.344970
# EDUCATION             13364148  4.364407
# FINANCE               12662106  4.115563
# WEATHER               12295164  4.243056
# LIFESTYLE             11832671  4.093355
# BUSINESS               9890245  4.098479
# FOOD_AND_DRINK         6325028  4.172340
# DATING                 3623544  3.970149
# COMICS                 2342071  4.181481
# HOUSE_AND_HOME         1929847  4.150000
# ART_AND_DESIGN         1419203  4.357377
# MEDICAL                1182971  4.166552
# AUTO_AND_VEHICLES      1163666  4.190411
# PARENTING               958331  4.300000
# LIBRARIES_AND_DEMO      906831  4.178125
# BEAUTY                  396240  4.278571
# EVENTS                  161018  4.435556

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# **Membuat Bar Plot**

# %% [markdown]
# **_Task 7:_**
# Lengkapi tahap agregasi untuk membuat dataframe yang mengelompokkan aplikasi berdasarkan Category.
# Buatlah bar plot dimana axis x adalah nama Category dan axis y adalah jumlah aplikasi pada setiap kategori, kemudian urutkan dari jumlah terbanyak

# %%
#

# %%
df2.groupby('Category').agg({
'App' : 'count'
 }).sort_values(by='App', ascending=False).rename({'App':'Total'}, axis=1).head()
# Out:
#           Total
# Category
# FAMILY     1832
# GAME        959
# TOOLS       827
# BUSINESS    420
# MEDICAL     395

# %%
cat_order = df2.groupby('Category').agg({
'App' : 'count'
 }).sort_values(by='App', ascending=False).rename({'App':'Total'}, axis=1).head()
X = cat_order.index
Y = cat_order.Total
my_colors = 'rgbkymc'
# bagian ini digunakan untuk membuat kanvas/figure
fig = plt.figure(figsize=(8,3),dpi=300)
fig.add_subplot()
# bagian ini digunakan untuk membuat bar plot
plt.barh(X,Y,)
# bagian ini digunakan untuk menyimpan plot dalam format image.png
plt.savefig('cat_order.png',bbox_inches="tight")

# %% [markdown]
# **Membuat Scatter Plot**

# %% [markdown]
# **_Task 8:_** Buatlah scatter plot untuk menampilkan hubungan dan persebaran apalikasi dilihat dari Review vs Rating.
# Ukuran scatter menggambarkan berapa banyak pengguna yang telah menginstall aplikasi

# %%
X = df2['Reviews'].values # axis x
Y = df2['Rating'].values # axis y
area = playstore['Installs'].values/10000000 # ukuran besar/kecilnya lingkaran scatter plot
fig = plt.figure(figsize=(5,5))
fig.add_subplot()
# isi nama method untuk scatter plot, variabel x, dan variabel y
plt.scatter(X,Y, s=area, alpha=0.3)
plt.xlabel('Reviews')
plt.ylabel('Rating')
plt.savefig('rev_rat.png',bbox_inches="tight")

# %% [markdown]
# **Membuat Histogram Size Distribution**

# %% [markdown]
# **_Task 9:_** Buatlah sebuah histogram yang menggambarkan distribusi Size aplikasi dalam satuan Mb(Megabytes). Histogram yang terbentuk terbagi menjadi 100 bins

# %%
X=(playstore.Size/1000000).values
fig = plt.figure(figsize=(5,5))
fig.add_subplot()
plt.hist(X,bins=100, density=True,  alpha=0.75)
plt.xlabel('Size')
plt.ylabel('Frequency')
plt.savefig('hist_size.png',bbox_inches="tight")

# %% [markdown]
# **_Task 10:_** Buatlah plot berdasarkan hasil analisis anda. Plot yang dibuat tidak diperbolehkan sama dengan plot yang sudah dicontohkan.

# %%
## code here
df2
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating  Reviews      Size  Installs  Type  Price Content Rating  \
# 0         4.1      159  19000000     10000  Free    0.0       Everyone
# 1         3.9      967  14000000    500000  Free    0.0       Everyone
# 2         4.7    87510   8700000   5000000  Free    0.0       Everyone
# 3         4.5   215644  25000000  50000000  Free    0.0           Teen
# 4         4.3      967   2800000    100000  Free    0.0       Everyone
# ...       ...      ...       ...       ...   ...    ...            ...
# 10836     4.5       38  53000000      5000  Free    0.0       Everyone
# 10837     5.0        4   3600000       100  Free    0.0       Everyone
# 10838     NaN        3   9500000      1000  Free    0.0       Everyone
# 10839     4.5      114  13134701      1000  Free    0.0     Mature 17+
# 10840     4.5   398307  19000000  10000000  Free    0.0       Everyone
#
#                           Genres      Last Updated         Current Ver  \
# 0                   Art & Design   January 7, 2018               1.0.0
# 1      Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2                   Art & Design    August 1, 2018               1.2.4
# 3                   Art & Design      June 8, 2018  Varies with device
# 4        Art & Design;Creativity     June 20, 2018                 1.1
# ...                          ...               ...                 ...
# 10836                  Education     July 25, 2017                1.48
# 10837                  Education      July 6, 2018                 1.0
# 10838                    Medical  January 20, 2017                 1.0
# 10839          Books & Reference  January 19, 2015  Varies with device
# 10840                  Lifestyle     July 25, 2018  Varies with device
#
#               Android Ver
# 0            4.0.3 and up
# 1            4.0.3 and up
# 2            4.0.3 and up
# 3              4.2 and up
# 4              4.4 and up
# ...                   ...
# 10836          4.1 and up
# 10837          4.1 and up
# 10838          2.2 and up
# 10839  Varies with device
# 10840  Varies with device
#
# [9659 rows x 13 columns]

# %% [markdown]
# ## Genre Aplikasi Dengan Harga Tertinggi

# %%
gen_order = df2.groupby('Genres').agg({
'Price' : 'max'
 }).sort_values(by='Price', ascending=False).rename({'Price':'Total'}, axis=1).head()
X = gen_order.index
Y = gen_order.Total
fig = plt.figure(figsize=(8,3),dpi=300)
fig.add_subplot()
plt.barh(X,Y,)
plt.savefig('gen_order.png',bbox_inches="tight")

# %% [markdown]
# ## Pembuktian

# %%
df2.sort_values(by='Price', ascending=False).head(50)
# Out:
#                                                     App       Category  \
# 4367                           I'm Rich - Trump Edition      LIFESTYLE
# 9934                  I'm Rich/Eu sou Rico/أنا غني/我很有錢      LIFESTYLE
# 5359                                 I am rich(premium)        FINANCE
# 5358                                         I am Rich!        FINANCE
# 5373                                 I AM RICH PRO PLUS        FINANCE
# 5356                                  I Am Rich Premium        FINANCE
# 5354                                     I am Rich Plus         FAMILY
# 5364                     I am rich (Most expensive app)        FINANCE
# 5369                                          I am Rich        FINANCE
# 5351                                          I am rich      LIFESTYLE
# 4197                             most expensive app (H)         FAMILY
# 5362                                      I Am Rich Pro         FAMILY
# 4362                                         💎 I'm rich      LIFESTYLE
# 9917                                        Eu Sou Rico        FINANCE
# 5366                                          I Am Rich         FAMILY
# 5357                                I am extremely Rich      LIFESTYLE
# 5355                                      I am rich VIP      LIFESTYLE
# 9719                                       EP Cook Book        MEDICAL
# 6692                                      cronometra-br   PRODUCTIVITY
# 6624                            BP Fitness Lead Scanner         EVENTS
# 9730                                            Lean EQ       BUSINESS
# 2253                          Vargo Anesthesia Mega App        MEDICAL
# 2390                          Language Therapy: Aphasia        MEDICAL
# 6559                          Dr.Dice - Sic bo analyzer         FAMILY
# 4134                      Norwegian For Kids & Babies F         FAMILY
# 2414                                       LTC AS Legal        MEDICAL
# 5360                                   I am Rich Person      LIFESTYLE
# 2301                            A Manual of Acupuncture        MEDICAL
# 9905                                        Eu sou Rico        FINANCE
# 2298                                 PTA Content Master        MEDICAL
# 8328                                  Guide to Nikon Df    PHOTOGRAPHY
# 2266                                           EMT PASS        MEDICAL
# 3039                            Golfshot Plus: Golf GPS         SPORTS
# 5489                          AP Art History Flashcards         FAMILY
# 9104                                           Dz kayas        FINANCE
# 4177                                    G-NetReport Pro          TOOLS
# 2280                     Advanced Comprehension Therapy        MEDICAL
# 2251   Human Anatomy Atlas 2018: Complete 3D Human Body        MEDICAL
# 2277  Muscle Premium - Human Anatomy, Kinesiology, B...        MEDICAL
# 7477                         USMLE Step 2 CK Flashcards         FAMILY
# 8719                                  DRAGON QUEST VIII         FAMILY
# 2297                               Hospitalist Handbook        MEDICAL
# 4848                                            Z PIVOT  COMMUNICATION
# 5036                                         NewTek NDI    PHOTOGRAPHY
# 5739                                         AW Toolbox       BUSINESS
# 7347                            boattheory.ch Full 2018         FAMILY
# 5361                             I am Rich Premium Plus        FINANCE
# 6837                                 SkyTest BU/GU Lite       BUSINESS
# 4203                            The World Ends With You           GAME
# 2256                         2017 EMRA Antibiotic Guide        MEDICAL
#
#       Rating  Reviews      Size  Installs  Type   Price Content Rating  \
# 4367     3.6      275   7300000     10000  Paid  400.00       Everyone
# 9934     NaN        0  40000000         0  Paid  399.99       Everyone
# 5359     3.5      472    965000      5000  Paid  399.99       Everyone
# 5358     3.8       93  22000000      1000  Paid  399.99       Everyone
# 5373     4.0       36  41000000      1000  Paid  399.99       Everyone
# 5356     4.1     1867   4700000     50000  Paid  399.99       Everyone
# 5354     4.0      856   8700000     10000  Paid  399.99       Everyone
# 5364     4.1      129   2700000      1000  Paid  399.99           Teen
# 5369     4.3      180   3800000      5000  Paid  399.99       Everyone
# 5351     3.8     3547   1800000    100000  Paid  399.99       Everyone
# 4197     4.3        6   1500000       100  Paid  399.99       Everyone
# 5362     4.4      201   2700000      5000  Paid  399.99       Everyone
# 4362     3.8      718  26000000     10000  Paid  399.99       Everyone
# 9917     NaN        0   1400000         0  Paid  394.99       Everyone
# 5366     3.6      217   4900000     10000  Paid  389.99       Everyone
# 5357     2.9       41   2900000      1000  Paid  379.99       Everyone
# 5355     3.8      411   2600000     10000  Paid  299.99       Everyone
# 9719     NaN        0   3200000         0  Paid  200.00       Everyone
# 6692     NaN        0   5400000         0  Paid  154.99       Everyone
# 6624     NaN        0   6700000         1  Paid  109.99       Everyone
# 9730     NaN        6  10000000        10  Paid   89.99       Everyone
# 2253     4.6       92  32000000      1000  Paid   79.99       Everyone
# 2390     NaN       10  28000000      1000  Paid   74.99       Everyone
# 6559     NaN        2   8500000        10  Paid   46.99       Everyone
# 4134     NaN        0  14000000         5  Paid   39.99       Everyone
# 2414     4.0        6   1300000       100  Paid   39.99       Everyone
# 5360     4.2      134   1800000      1000  Paid   37.99       Everyone
# 2301     3.5      214  68000000      1000  Paid   33.99       Everyone
# 9905     NaN        0   2600000         0  Paid   30.99       Everyone
# 2298     4.2       64  41000000      1000  Paid   29.99       Everyone
# 8328     NaN        1    663000        10  Paid   29.99       Everyone
# 2266     3.4       51   2400000      1000  Paid   29.99       Everyone
# 3039     4.1     3387  25000000     50000  Paid   29.99       Everyone
# 5489     5.0        1  96000000        10  Paid   29.99     Mature 17+
# 9104     NaN        0  14000000         1  Paid   28.99       Everyone
# 4177     NaN        0   1600000        10  Paid   25.99       Everyone
# 2280     NaN        3  62000000       100  Paid   24.99       Everyone
# 2251     4.5     2921  25000000    100000  Paid   24.99       Everyone
# 2277     4.2      168  25000000     10000  Paid   24.99       Everyone
# 7477     5.0        1  40000000        10  Paid   19.99       Everyone
# 8719     4.5     7812  27000000     50000  Paid   19.99   Everyone 10+
# 2297     4.8       12  18000000      1000  Paid   19.99       Everyone
# 4848     NaN        0   5700000        10  Paid   19.99       Everyone
# 5036     3.5       77   1200000      1000  Paid   19.99       Everyone
# 5739     NaN        3  13000000       100  Paid   19.90       Everyone
# 7347     4.7       54  50000000      1000  Paid   19.40       Everyone
# 5361     4.6      459   2000000     10000  Paid   18.99       Everyone
# 6837     2.9       28  20000000       500  Paid   17.99       Everyone
# 4203     4.6     4108  13000000     10000  Paid   17.99   Everyone 10+
# 2256     4.4       12   3800000      1000  Paid   16.99       Everyone
#
#              Genres        Last Updated Current Ver   Android Ver
# 4367      Lifestyle         May 3, 2018       1.0.1    4.1 and up
# 9934      Lifestyle    December 1, 2017       MONEY    4.1 and up
# 5359        Finance         May 1, 2017         3.4    4.4 and up
# 5358        Finance   December 11, 2017         1.0    4.1 and up
# 5373        Finance       June 25, 2018       1.0.2    4.1 and up
# 5356        Finance   November 12, 2017         1.6    4.0 and up
# 5354  Entertainment        May 19, 2018         3.0    4.4 and up
# 5364        Finance    December 6, 2017           2  4.0.3 and up
# 5369        Finance      March 22, 2018         1.0    4.2 and up
# 5351      Lifestyle    January 12, 2018         2.0  4.0.3 and up
# 4197  Entertainment       July 16, 2018         1.0    7.0 and up
# 5362  Entertainment        May 30, 2017        1.54    1.6 and up
# 4362      Lifestyle      March 11, 2018       1.0.0    4.4 and up
# 9917        Finance       July 11, 2018         1.0  4.0.3 and up
# 5366  Entertainment       June 22, 2018         1.5    4.2 and up
# 5357      Lifestyle        July 1, 2018         1.0    4.0 and up
# 5355      Lifestyle       July 21, 2018       1.1.1    4.3 and up
# 9719        Medical       July 26, 2015         1.0    3.0 and up
# 6692   Productivity   November 24, 2017       1.0.0    4.1 and up
# 6624         Events     August 23, 2017       0.0.1    4.1 and up
# 9730       Business   February 14, 2017         1.0    4.1 and up
# 2253        Medical       June 18, 2018        19.0  4.0.3 and up
# 2390        Medical       June 25, 2018       3.1.1  4.0.3 and up
# 6559  Entertainment    November 5, 2016         1.0  4.0.3 and up
# 4134      Education  September 24, 2015         1.0    4.0 and up
# 2414        Medical       April 4, 2018       3.0.1    4.1 and up
# 5360      Lifestyle       July 18, 2017         1.0  4.0.3 and up
# 2301        Medical     October 2, 2017      2.1.35    4.0 and up
# 9905        Finance     January 9, 2018         1.0    4.0 and up
# 2298        Medical   December 22, 2015         2.1    2.2 and up
# 8328    Photography   February 18, 2014       2.0.0  4.0.3 and up
# 2266        Medical    October 22, 2014       2.0.2    4.0 and up
# 3039         Sports       July 11, 2018      4.18.0    4.1 and up
# 5489      Education    January 19, 2016        3.30    4.0 and up
# 9104        Finance       July 12, 2018         1.0    4.2 and up
# 4177          Tools       June 14, 2018         5.0    4.0 and up
# 2280        Medical     October 5, 2017         1.2  4.0.3 and up
# 2251        Medical        May 25, 2018   2018.5.47    5.0 and up
# 2277        Medical     August 11, 2017      7.1.17    4.4 and up
# 7477      Education        May 26, 2014        2.47    2.2 and up
# 8719   Role Playing       April 4, 2017       1.1.4    4.0 and up
# 2297        Medical        June 5, 2017       6.0.4    4.1 and up
# 4848  Communication       July 11, 2018         1.3    4.2 and up
# 5036    Photography    October 26, 2016         1.1    4.1 and up
# 5739       Business   December 22, 2016       1.6.2    4.0 and up
# 7347      Education   November 18, 2017       3.1.2    4.2 and up
# 5361        Finance   February 17, 2018         1.1  4.0.3 and up
# 6837       Business    October 24, 2017       2.0.5    3.0 and up
# 4203         Arcade   December 14, 2015       1.0.4    4.0 and up
# 2256        Medical    January 27, 2017       1.0.5  4.0.3 and up

# %%
#

# %%
#
